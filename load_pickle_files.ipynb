# %% [markdown]
# <a href="https://colab.research.google.com/github/Amritha07dec/MCN/blob/sample_generation/load_pickle_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive/sample_generation"
# Out:
# 'ode_simulations (2).zip'

# %%
import zipfile
zip_path = "/content/drive/MyDrive/sample_generation/ode_simulations (2).zip"
extract_path = "/content/extracted_data"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extracted files:\n", os.listdir(extract_path))
# Out:
# Extracted files:
# ...

# %%
import zipfile
import os
import pickle

# Define file paths
zip_path = "/content/ode_simulations (2).zip"  # Change this to your uploaded file name
extract_path = "/content/extracted_data"

# Extract ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extracted files:", os.listdir(extract_path))

# Load Pickle Files
pickle_files = [f for f in os.listdir(extract_path) if f.endswith(".pkl")]
data_dict = {}

for file in pickle_files:
    file_path = os.path.join(extract_path, file)
    with open(file_path, "rb") as f:
        data_dict[file] = pickle.load(f)

print("Loaded pickle files:", data_dict.keys())
# Out:
# Extracted files: ['Lorenz_Set-3_Deg-Poly_2_0_Params-10.0_100.0_2.6666666666666665_IC-1.5_1.5_1.5.pkl', 'Duffing_Oscillator_Set-2_Deg-Poly_3_0_Params-0.2_1.0_0.5_0.8_1.0_IC-1.25_0.0.pkl', 'Rossler_Set-2_Deg-Poly_2_0_Params-0.1_0.1_6.0_IC-0.5_0.5_0.5.pkl', 'Lorenz_Set-1_Deg-Poly_2_0_Params-10.0_28.0_2.6666666666666665_IC-1.5_1.5_1.5.pkl', 'Van_der_Pol_Set-4_Deg-Poly_3_0_Params-20.0_IC--0.1_-0.1.pkl', 'Linear_3D_Coupled_Oscillators_Set-2_Deg-Poly_1_0_Params-0.5_0.5_0.5_IC-0.75_0.75_0.75.pkl', 'Van_der_Pol_Set-1_Deg-Poly_3_0_Params-0.5_IC-0.75_0.0.pkl', 'Lorenz_Set-3_Deg-Poly_2_0_Params-10.0_100.0_2.6666666666666665_IC-5.5_5.5_5.5.pkl', 'Lorenz96_Set-1_Deg-Poly_2_0_Params-10.0_4_IC-0.0_0.0_0.0_0.0.pkl', 'Lotka_Volterra_Cubic_Set-1_Deg-Poly_3_0_Params-1.0_0.5_0.1_1.0_0.1_IC-0.0_0.0.pkl', 'Lorenz_Set-2_Deg-Poly_2_0_Params-10.0_15.0_2.6666666666666665_IC--0.125_-0.125_-0.125.pkl', 'Lotka_Volterra_Cubic_Set-2_Deg-Poly_3_0_Params-1.0_0.5_0.3_1.0_0.2_IC-0.5249999999999999_0.375.pkl', 'Lotka_Vo
# ...
