# %% [markdown]
# <a href="https://colab.research.google.com/github/Amritha07dec/MCN/blob/main/ODEST_no_of_PF_single_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Give the number of perturbation factors and the smaples will be generated for a single system**

# %%
# !git clone https://github.com/Amritha07dec/MCN.git
# %cd MCN
# Out:
# Cloning into 'MCN'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 73 (delta 32), reused 18 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (73/73), 32.58 MiB | 6.10 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# /content/MCN

# %% [markdown]
# # ODE simulator

# %% [markdown]
# ## Importing dependencies

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import yaml

from scipy.integrate import solve_ivp

# %% [markdown]
# ## Code for simulation with a generic ODE RHS

# %%
def simulate_ode_system(rhs_func, t_span, y0, params, solver='RK45', t_eval=None):
    """
    Simulate the ODE system.

    Parameters:
    - rhs_func: The right-hand side of the ODE as a function of (t, y, params).
    - t_span: Tuple (t_0, t_final), the time span for the simulation.
    - y0: Initial conditions as an array.
    - params: Parameters required by the rhs_func.
    - solver: The ODE solver method ('RK45', 'RK23', 'DOP853', 'LSODA', etc.).
    - t_eval: Array of time points at which to store the solution.

    Returns:
    - sol: Solution object containing times and states.
    """
    # Define the ODE system as a lambda function to pass the parameters
    def ode_func(t, y):
        return rhs_func(t, y, params)

    # Solve the ODE system
    sol = solve_ivp(ode_func, t_span, y0, method=solver, t_eval=t_eval)

    return sol


# Updated phase space plot function
def plot_phase_space(sol, state_indices=(0, 1, 2)):
    """
    Plots the phase space of the solution. Automatically switches to 3D if there are more than two states.

    Args:
    sol: Solution object from the ODE solver (such as the one returned by scipy's solve_ivp).
    state_indices: Tuple specifying which state variables to plot (default is (0, 1)).
                   For a 3D plot, pass 3 indices, for example (0, 1, 2).
    """
    y = sol.y
    num_states = y.shape[0]

    # 2D phase space
    if num_states == 2 or len(state_indices) ==2:
        plt.figure(figsize=(8, 6))
        plt.plot(y[state_indices[0]], y[state_indices[1]], lw=0.8)
        plt.xlabel(f"State {state_indices[0]}")
        plt.ylabel(f"State {state_indices[1]}")
        plt.title("2D Phase Space")
        plt.grid(True)
        plt.show()

    # 3D phase space if the system has more than two states
    elif len(state_indices) == 3 and num_states >= 3:
        fig = plt.figure(figsize=(10, 8))
        ax = fig.add_subplot(111, projection='3d')
        ax.plot(y[state_indices[0]], y[state_indices[1]], y[state_indices[2]], lw=0.8)
        ax.set_xlabel(f"State {state_indices[0]}")
        ax.set_ylabel(f"State {state_indices[1]}")
        ax.set_zlabel(f"State {state_indices[2]}")
        ax.set_title("3D Phase Space")
        plt.show()

    else:
        print("State indices must be 2 or 3 for phase space plotting.")
def plot_trajectories(sol):
    """
    Plot the trajectories of all state variables over time.

    Parameters:
    - sol: Solution object from solve_ivp.
    """
    plt.figure(figsize=(8, 6))
    for i in range(sol.y.shape[0]):
        plt.plot(sol.t, sol.y[i], label=f'State {i}')
    plt.xlabel('Time')
    plt.ylabel('State Variables')
    plt.title('State Variables Over Time')
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Demo of simulating a system from the model dictionary

# %%
# importing models dictionary
from ode_models_dictionary import ode_systems

# %%
# Example of how to access the rhs function and parameters_and_IC for the Lorenz system
#system_name = 'Damped_Oscilllator'
#system_name = 'Lorenz'                             #DCF=('Poly', 2, 0)
#system_name = 'Van_der_Pol'                        #DCF=('Poly', 3, 0)
#system_name = 'Lorenz96'                           #DCF=('Poly', 2, 0)
#system_name = 'Rossler'                            #DCF=('Poly', 2, 0)
#system_name = 'Linear_1D'                          #DCF=('Poly', 1, 0)
#system_name = 'Linear_2D_Harmonic_Oscillator'      #DCF=('Poly', 1, 0)
#system_name = 'Linear_3D_Coupled_Oscillators'      #DCF=('Poly', 1, 0)
#system_name = 'Linear_4D_Coupled_Oscillators'      #DCF=('Poly', 1, 0)
#system_name = 'Linear_5D_Coupled_Oscillators'      #DCF=('Poly', 1, 0)
#system_name = 'Duffing_Oscillator'                 #DCF=('Poly', 3, 0)
system_name = 'Quartic_Oscillator'                 #DCF=('Poly', 4, 0)
#system_name = 'Lotka_Volterra_Cubic'               #DCF=('Poly', 3, 0)

import os
import pickle
import glob
import numpy as np



# ==== USER SETTINGS ====
num_samples = 8            # How many perturbations per (param, IC) combo
perturb_direction = "positive"  # Choose "positive" or "negative"
# ========================

# Generate perturbation factors list
step = 0.15

if perturb_direction == "positive":
    perturbation_factors = [step * i for i in range(1, num_samples + 1)]
elif perturb_direction == "negative":
    perturbation_factors = [-step * i for i in range(1, num_samples + 1)]
else:
    raise ValueError("perturb_direction must be 'positive' or 'negative'")


# Extract the specific system details
system_data = ode_systems[system_name]
rhs_func = system_data['rhs_function']
parameters_and_IC = system_data['parameters_and_IC']
degree = system_data['DCF_values']

# Folder to save pickle files
folder_name = "pickle_files"
os.makedirs(folder_name, exist_ok=True)

# Counter for generated samples
sample_count = 0

# Loop over each parameter & initial condition set
for idx, (params, initial_conditions, description) in enumerate(parameters_and_IC):
    for factor in perturbation_factors:
        # Perturb initial conditions
        perturbed_ic = [ic + factor * ic for ic in initial_conditions]

        print(f"\nSimulating {system_name} (Set {idx + 1}) with perturbation factor {factor}")
        print(f"Parameters: {params}")
        print(f"Initial conditions: {perturbed_ic}")
        print(f"Expected behavior: {description}")

        # Solve the system
        t_span = (0, 20)
        t_eval = np.linspace(t_span[0], t_span[1], 10000)
        sol = simulate_ode_system(rhs_func, t_span, perturbed_ic, params, solver='RK45', t_eval=t_eval)

        # Plot (optional)
        plot_trajectories(sol)

        # Save sample
        time_series_sample = {
            "Time series": sol,
            "degree": degree
        }

        # Construct filename
        degree_str = "_".join(map(str, degree))
        params_str = "_".join(map(str, params))
        ic_str = "_".join(f"{x:.2f}" for x in perturbed_ic)  # Keep decimals reasonable
        file_name = os.path.join(folder_name, f"{system_name}_Set-{idx + 1}_Deg-{degree_str}_Params-{params_str}_IC-{ic_str}.pkl")

        with open(file_name, "wb") as f:
            pickle.dump(time_series_sample, f)

        print(f"Pickle file saved at: {file_name}")
        sample_count += 1

# List all saved pickle files
pickle_files = glob.glob(f"{folder_name}/*.pkl")
print("\nAll saved pickle files:")
print("\n".join(pickle_files))
# Out:
# Simulating Quartic_Oscillator (Set 1) with perturbation factor 0.15
# Parameters: [1.0, 0.5]
# Initial conditions: [1.15, 0.0]
# Expected behavior: cyclic
# Pickle file saved at: pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.15_0.00.pkl
#
# Simulating Quartic_Oscillator (Set 1) with perturbation factor 0.3
# Parameters: [1.0, 0.5]
# Initial conditions: [1.3, 0.0]
# Expected behavior: cyclic
# Pickle file saved at: pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.30_0.00.pkl
#
# Simulating Quartic_Oscillator (Set 1) with perturbation factor 0.44999999999999996
# Parameters: [1.0, 0.5]
# Initial conditions: [1.45, 0.0]
# Expected behavior: cyclic
# Pickle file saved at: pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.45_0.00.pkl
#
# Simulating Quartic_Oscillator (Set 1) with perturbation factor 0.6
# Parameters: [1.0, 0.5]
# Initial conditions: [1.6, 0.0]
# Expected behavior: cyclic
# Pickle file saved at: pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.60_0.00.pkl
#
# Simulating Quartic_Oscillator (Set 1) with perturbation factor 0.75
# Parameters: [1.0, 0.5]
# Initial conditions: [1.75, 0.0]
# Expected behavior: cyclic
# Pickle file saved at: pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.75_0.00.pkl
#
# Simulating Quartic_Oscillator (Set 1) with perturbation factor 0.8999999999999999
# Parameters: [1.0, 0.5]
# Initial conditions: [1.9, 0.0]
# Expected behavior: cyclic
# Pickle file saved at: pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.90_0.00.pkl
#
# Simulating Quartic_Oscillator (Set 1) with perturbation factor 1.05
# Parameters: [1.0, 0.5]
# Initial conditions: [2.05, 0.0]
# Expected behavior: cyclic
# Pickle file saved at: pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-2.05_0.00.pkl
#
# Simulating Quartic_Oscillator (Set 1) with perturbation factor 1.2
# Parameters: [1.0, 0.5]
# Initial conditions: [2.2, 0.0]
# Expected behavior: cyclic
# Pickle file saved at: pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-2.20_0.00.pkl
#
# Simulating Quartic_Oscillator (Set 2) with perturbation factor 0.15
# Parameters: [1.0, 1.0]
# Initial conditions: [0.575, 0.0]
# Expected behavior: complex
# Pickle file saved at: pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.57_0.00.pkl
#
# Simulating Quartic_Oscillator (Set 2) with perturbation factor 0.3
# Parameters: [1.0, 1.0]
# Initial conditions: [0.65, 0.0]
# Expected behavior: complex
# Pickle file saved at: pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.65_0.00.pkl
#
# Simulating Quartic_Oscillator (Set 2) with perturbation factor 0.44999999999999996
# Parameters: [1.0, 1.0]
# Initial conditions: [0.725, 0.0]
# Expected behavior: complex
# Pickle file saved at: pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.72_0.00.pkl
#
# Simulating Quartic_Oscillator (Set 2) with perturbation factor 0.6
# Parameters: [1.0, 1.0]
# Initial conditions: [0.8, 0.0]
# Expected behavior: complex
# Pickle file saved at: pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.80_0.00.pkl
#
# Simulating Quartic_Oscillator (Set 2) with perturbation factor 0.75
# Parameters: [1.0, 1.0]
# Initial conditions: [0.875, 0.0]
# Expected behavior: complex
# Pickle file saved at: pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.88_0.00.pkl
#
# Simulating Quartic_Oscillator (Set 2) with perturbation factor 0.8999999999999999
# Parameters: [1.0, 1.0]
# Initial conditions: [0.95, 0.0]
# Expected behavior: complex
# Pickle file saved at: pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.95_0.00.pkl
#
# Simulating Quartic_Oscillator (Set 2) with perturbation factor 1.05
# Parameters: [1.0, 1.0]
# Initial conditions: [1.025, 0.0]
# Expected behavior: complex
# Pickle file saved at: pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-1.02_0.00.pkl
#
# Simulating Quartic_Oscillator (Set 2) with perturbation factor 1.2
# Parameters: [1.0, 1.0]
# Initial conditions: [1.1, 0.0]
# Expected behavior: complex
# Pickle file saved at: pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-1.10_0.00.pkl
#
# All saved pickle files:
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.20_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-2.50_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.80_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC--0.38_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-3.00_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-0.00_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-1.12_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-1.38_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.00_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.50_0.00.pkl
# pickle_files/Lorenz_Set-2_Deg-Poly_2_0_Params-10.0_15.0_2.6666666666666665_IC-0.62_0.62_0.62.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.50_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.38_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.88_0.00.pkl
# pickle_files/Lorenz_Set-3_Deg-Poly_2_0_Params-10.0_100.0_2.6666666666666665_IC-2.00_2.00_2.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.80_0.00.pkl
# pickle_files/Lorenz_Set-1_Deg-Poly_2_0_Params-10.0_28.0_2.6666666666666665_IC-1.25_1.25_1.25.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.57_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC--0.75_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC--0.25_0.00.pkl
# pickle_files/Lorenz_Set-2_Deg-Poly_2_0_Params-10.0_15.0_2.6666666666666665_IC-0.50_0.50_0.50.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.75_0.00.pkl
# pickle_files/Lorenz_Set-3_Deg-Poly_2_0_Params-10.0_100.0_2.6666666666666665_IC-2.50_2.50_2.50.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-1.50_0.00.pkl
# pickle_files/Lorenz_Set-3_Deg-Poly_2_0_Params-10.0_100.0_2.6666666666666665_IC-1.50_1.50_1.50.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.95_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.70_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-0.50_0.00.pkl
# pickle_files/Lorenz_Set-1_Deg-Poly_2_0_Params-10.0_28.0_2.6666666666666665_IC-1.00_1.00_1.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.90_0.00.pkl
# pickle_files/Lorenz_Set-1_Deg-Poly_2_0_Params-10.0_28.0_2.6666666666666665_IC-0.75_0.75_0.75.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.72_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.30_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC--0.50_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-2.75_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.15_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.62_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.60_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.45_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.60_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.25_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.75_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.70_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC--0.25_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.12_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-2.20_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.40_0.00.pkl
# pickle_files/Lorenz_Set-2_Deg-Poly_2_0_Params-10.0_15.0_2.6666666666666665_IC-0.38_0.38_0.38.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-1.25_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-2.00_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.55_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC--1.00_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.25_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-0.25_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-2.05_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.10_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-1.90_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-2.25_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-1.02_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-1_Deg-Poly_4_0_Params-1.0_0.5_IC-0.75_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC--0.12_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-1.00_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC--0.50_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.85_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.65_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-1.10_0.00.pkl
# pickle_files/Quartic_Oscillator_Set-2_Deg-Poly_4_0_Params-1.0_1.0_IC-0.00_0.00.pkl

# %%
# Print file names
print("Saved pickle files:")
for file in pickle_files:
    print(file)
# Print total count of generated samples
print(f"\nTotal number of samples generated and saved: {sample_count}")
# Out:
# Saved pickle files:
# pickle_files/Lorenz_Set-2_Deg-Poly_2_0_Params-10.0_15.0_2.6666666666666665_IC-0.62_0.62_0.62.pkl
# pickle_files/Lorenz_Set-3_Deg-Poly_2_0_Params-10.0_100.0_2.6666666666666665_IC-2.00_2.00_2.00.pkl
# pickle_files/Lorenz_Set-1_Deg-Poly_2_0_Params-10.0_28.0_2.6666666666666665_IC-1.25_1.25_1.25.pkl
# pickle_files/Lorenz_Set-2_Deg-Poly_2_0_Params-10.0_15.0_2.6666666666666665_IC-0.50_0.50_0.50.pkl
# pickle_files/Lorenz_Set-3_Deg-Poly_2_0_Params-10.0_100.0_2.6666666666666665_IC-2.50_2.50_2.50.pkl
# pickle_files/Lorenz_Set-3_Deg-Poly_2_0_Params-10.0_100.0_2.6666666666666665_IC-1.50_1.50_1.50.pkl
# pickle_files/Lorenz_Set-1_Deg-Poly_2_0_Params-10.0_28.0_2.6666666666666665_IC-1.00_1.00_1.00.pkl
# pickle_files/Lorenz_Set-1_Deg-Poly_2_0_Params-10.0_28.0_2.6666666666666665_IC-0.75_0.75_0.75.pkl
# pickle_files/Lorenz_Set-2_Deg-Poly_2_0_Params-10.0_15.0_2.6666666666666665_IC-0.38_0.38_0.38.pkl
#
# Total number of samples generated and saved: 9
